# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd
import numpy as np
# Out:
# c:\Users\isaac\miniconda3\envs\data-science\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %%
df = pd.read_csv('data/ourworldindata_covid.csv')

# %%
df.describe()
# Out:
#         total_cases     new_cases  new_cases_smoothed  \
# count  4.972530e+05  4.942790e+05        4.930740e+05
# mean   1.382299e+07  1.098854e+04        1.101544e+04
# std    7.232246e+07  1.195768e+05        1.020819e+05
# min    0.000000e+00  0.000000e+00        0.000000e+00
# 25%    8.544000e+03  0.000000e+00        0.000000e+00
# 50%    8.085800e+04  0.000000e+00        5.857143e+00
# 75%    1.044943e+06  7.700000e+01        2.238571e+02
# max    7.781636e+08  8.401906e+06        6.402033e+06
#
#        total_cases_per_million  new_cases_per_million  \
# count            497253.000000          494279.000000
# mean             127231.714734             103.172983
# std              173097.774202            1004.101224
# min                   0.000000               0.000000
# 25%                2880.198700               0.000000
# 50%               42892.805000               0.000000
# 75%              184227.030000               9.171056
# ...

# %%
df.head()
# Out:
#        country        date  total_cases  new_cases  new_cases_smoothed  \
# 0  Afghanistan  2020-01-01          NaN        NaN                 NaN
# 1  Afghanistan  2020-01-02          NaN        NaN                 NaN
# 2  Afghanistan  2020-01-03          NaN        NaN                 NaN
# 3  Afghanistan  2020-01-04          0.0        0.0                 NaN
# 4  Afghanistan  2020-01-05          0.0        0.0                 NaN
#
#    total_cases_per_million  new_cases_per_million  \
# 0                      NaN                    NaN
# 1                      NaN                    NaN
# 2                      NaN                    NaN
# 3                      0.0                    0.0
# 4                      0.0                    0.0
#
#    new_cases_smoothed_per_million  total_deaths  new_deaths  ...  population  \
# 0                             NaN           NaN         NaN  ...  40578801.0
# 1                             NaN           NaN         NaN  ...  40578801.0
# ...
